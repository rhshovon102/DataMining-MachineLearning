# %% [markdown]
# <a href="https://colab.research.google.com/github/rakibhasan3948/DataMining-MachineLearning/blob/main/K_NearestNeighbors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

df = pd.read_csv('/content/Iris_Data.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
le = LabelEncoder()

# %%
df.species = le.fit_transform(df.species)

# %%
df.species.unique()
# Out:
# array([0, 1, 2])

# %%
df.species.value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: species, dtype: int64

# %%
x = df.iloc[:,0:4]
y = df.iloc[:,4:]

# %%
from os import name
import matplotlib.pyplot as plt
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.scatter(df.sepal_length[0:50],df.sepal_width[0:50], marker = "+")
plt.scatter(df.sepal_length[50:100],df.sepal_width[50:100], marker = ".")
plt.scatter(df.sepal_length[100:150],df.sepal_width[100:150], marker = "*")

# %%
x.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
from tables.tests.test_suite import test
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
knn = KNeighborsClassifier()

# %%
knn = knn.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
knn.score(x_test,y_test)
# Out:
# 1.0

# %%
knn.predict([[5.1,	3.5,	1.4,	0.2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0])
